# %%
import pygame
import time
import random
from scipy.spatial import distance 
import cProfile
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class Entorno:
    def __init__(self, tipo, posicion, energia,recuperacion):
        self.tipo = tipo
        self.posicion = posicion  # (x, y) tuple
        self.energia = energia
        self.recuperacion = int(recuperacion/4)
        self.recuperacion_maxima = recuperacion
        
    def disponible(self):
        return self.recuperacion == 0

    def cooldown(self):
        if self.recuperacion > 0:
            self.recuperacion -= 1
    def __str__(self):
        return f"_________ Tipo: {self.tipo}, Posición: {self.posicion}, CD: {self.recuperacion}, Energía: {self.energia}"

# %%
class Organismo:
    def __init__(self, tipo, posicion, energia):
        self.tipo = tipo
        self.posicion = posicion  # (x, y)
        self.energia = energia
        self.energia_maxima = 150  # Energía máxima que puede tener el organismo

    def mover(self):
        # Movimiento aleatorio en una cuadrícula
        if self.tipo == "conejo":
            best,objetivo = 9999,0
            for entorno in mundo.entornos:
                if entorno.tipo == "arbusto" and self.radio_busqueda(entorno,25):
                    distancia = distance.euclidean(self.posicion, entorno.posicion)
                    cooldown = entorno.recuperacion
                    energia = entorno.energia
                    puntos = distancia+(cooldown*3.5)-(energia*.6)
                    if puntos < best:
                        best = puntos
                        objetivo = entorno.posicion
            if objetivo == 0:
                dx = random.choice([-5, 0, 5])
                dy = random.choice([-5, 0, 5])
            else:
                res = [objetivo[i]-self.posicion[i] for i in range(2)]
                direccion = [-5 if i < 0 else 5 if i > 0 else 0 for i in res]
                dx,dy = direccion[0],direccion[1]

        if self.tipo == "zorro":
            best,objetivo = 9999,0
            for organismo in mundo.organismos:
                if organismo.tipo == "conejo" and self.radio_busqueda(organismo, 35):
                    distancia = distance.euclidean(self.posicion,organismo.posicion)
                    energia = organismo.energia
                    puntos = distancia+energia*.4
                    if puntos < best:
                        best = puntos
                        objetivo = organismo.posicion
            if objetivo == 0:
                dx = random.choice([-10, -5, 0, 5, 10])
                dy = random.choice([-10, -5, 0, 5, 10])
            else:
                res = [objetivo[i]-self.posicion[i] for i in range(2)] #aqui falta poner el -10 y el 10 
                direccion = [-5 if i < 0 else 5 if i > 0 else 0 for i in res]
                dx,dy = direccion[0],direccion[1]
            
        self.posicion = (self.posicion[0] + dx, self.posicion[1] + dy)
        if dx == 0 and dy == 0:
            self.energia = round(self.energia - .2,1)
        else:
            self.energia = round(self.energia - 1,1)
            
    def alimentarse(self, mundo):
        # Los conejos Se alimentan de arbustos adyacentes
        if self.tipo == "conejo":
            for entorno in mundo.entornos:
                if entorno.tipo == "arbusto" and self.radio_busqueda(entorno,5) and entorno.disponible():
                    self.energia = min(self.energia + entorno.energia + random.randint(-5, 5), self.energia_maxima)
                    entorno.recuperacion = entorno.recuperacion_maxima
                    break

    def reproducirse(self):
        # Se reproduce si la energía es mayor que un umbral
        if self.energia > 80:
            self.energia //= 2  # Reduce la energía a la mitad
            hijo_posicion = (self.posicion[0] + random.choice([-5, 5]),
                             self.posicion[1] + random.choice([-5, 5]))
            return Organismo(self.tipo, hijo_posicion, self.energia)
        return None

    def cazar(self, mundo):
        # Los zorros cazan conejos adyacentes
        if self.tipo == "zorro":
            for organismo in mundo.organismos:
                if organismo.tipo == "conejo" and self.radio_busqueda(organismo,10):
                    self.energia = min(self.energia + organismo.energia + random.randint(0, 25), self.energia_maxima)
                    mundo.organismos.remove(organismo)
                    break
    def morir(self):
        if self.energia <= 0:
            mundo.organismos.remove(self)

    
    def radio_busqueda(self, otro_organismo,radio):
        dx = abs(self.posicion[0] - otro_organismo.posicion[0])
        dy = abs(self.posicion[1] - otro_organismo.posicion[1])
        return dx <= radio and dy <= radio

    def __str__(self):
        return f"Tipo: {self.tipo}, Posición: {self.posicion}, Energía: {self.energia}"

# %%
class Mundo:
    def __init__(self, tamaño):
        self.tamaño = tamaño  # (ancho, alto)
        self.organismos = []
        self.entornos = []
        self.ciclos = 0

    def agregar_organismo(self, organismo):
        self.organismos.append(organismo)

    def agregar_entorno(self, entorno):
        self.entornos.append(entorno)
    
    def actualizar(self):
        self.ciclos+=1
        nuevos_organismos = []
        for entorno in self.entornos:
            entorno.cooldown()
        for organismo in self.organismos:
            organismo.mover()
            organismo.alimentarse(self)
            organismo.cazar(self)
            organismo.morir()
            nuevo_organismo = organismo.reproducirse()
            if nuevo_organismo:
                nuevos_organismos.append(nuevo_organismo)
        self.organismos.extend(nuevos_organismos)

    def mostrar_estado(self):
        print(f"--- ciclo {self.ciclos} ---")
        for organismo in self.organismos:
            print(organismo)
        for entorno in self.entornos:
            print(entorno)
# # Ejecutar la simulación
# for paso in range(30):
#     print(f"Paso {paso + 1}:")
#     mundo.actualizar()
#     mundo.mostrar_estado()
#     print("---")

# %%
# Inicializar el mundo y agregar organismos
mundo = Mundo(tamaño=(20, 20))
organismos = []
organismos.append(Organismo(tipo="conejo", posicion=(100, 100), energia=45))
organismos.append(Organismo(tipo="conejo", posicion=(70, 170), energia=45))
organismos.append(Organismo(tipo="zorro", posicion=(120, 130), energia=70))

entornos = []
for i in range(15):
    n = random.randint(0,2)
    entornos.append(Entorno(tipo="arbusto",posicion=(random.randint(10, 40)*5,random.randint(10, 40)*5),energia=[20,70,120][n],recuperacion=[20,55,80][n]))  

for org in organismos:
    mundo.agregar_organismo(org)
for ent in entornos:
    mundo.agregar_entorno(ent)

# %%
mundo.mostrar_estado()
mundo.actualizar()
mundo.mostrar_estado()
# Out:
# --- ciclo 12 ---
# Tipo: conejo, Posición: (110, 105), Energía: 41.0
# Tipo: conejo, Posición: (65, 190), Energía: 36.2
# Tipo: zorro, Posición: (120, 165), Energía: 58.8
# _________ Tipo: arbusto, Posición: (190, 65), CD: 8, Energía: 120
# _________ Tipo: arbusto, Posición: (165, 165), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (175, 195), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (75, 105), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (140, 185), CD: 8, Energía: 120
# _________ Tipo: arbusto, Posición: (110, 105), CD: 1, Energía: 70
# _________ Tipo: arbusto, Posición: (100, 175), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (105, 190), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (195, 125), CD: 8, Energía: 120
# _________ Tipo: arbusto, Posición: (135, 90), CD: 1, Energía: 70
# _________ Tipo: arbusto, Posición: (90, 50), CD: 8, Energía: 120
# _________ Tipo: arbusto, Posición: (195, 135), CD: 1, Energía: 70
# _________ Tipo: arbusto, Posición: (165, 95), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (135, 115), CD: 1, Energía: 70
# _________ Tipo: arbusto, Posición: (195, 60), CD: 0, Energía: 20
# --- ciclo 13 ---
# Tipo: conejo, Posición: (110, 105), Energía: 53.0
# Tipo: conejo, Posición: (65, 190), Energía: 36.0
# Tipo: zorro, Posición: (110, 175), Energía: 57.8
# Tipo: conejo, Posición: (115, 110), Energía: 53.0
# _________ Tipo: arbusto, Posición: (190, 65), CD: 7, Energía: 120
# _________ Tipo: arbusto, Posición: (165, 165), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (175, 195), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (75, 105), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (140, 185), CD: 7, Energía: 120
# _________ Tipo: arbusto, Posición: (110, 105), CD: 55, Energía: 70
# _________ Tipo: arbusto, Posición: (100, 175), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (105, 190), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (195, 125), CD: 7, Energía: 120
# _________ Tipo: arbusto, Posición: (135, 90), CD: 0, Energía: 70
# _________ Tipo: arbusto, Posición: (90, 50), CD: 7, Energía: 120
# _________ Tipo: arbusto, Posición: (195, 135), CD: 0, Energía: 70
# _________ Tipo: arbusto, Posición: (165, 95), CD: 0, Energía: 20
# _________ Tipo: arbusto, Posición: (135, 115), CD: 0, Energía: 70
# _________ Tipo: arbusto, Posición: (195, 60), CD: 0, Energía: 20

# %%
pygame.init()
pantalla = pygame.display.set_mode((200, 200))
clock = pygame.time.Clock()
running = True

while running:
    clock.tick(60)
    for evento in pygame.event.get():
        if evento.type == pygame.QUIT:
            running = False
            pygame.quit()
    if not running:
        break

    pantalla.fill((255, 255, 255))
    for entorno in mundo.entornos:
        pygame.draw.circle(pantalla, (128, 255, 128), entorno.posicion, 2.5)
    for organismo in mundo.organismos:
        if organismo.tipo == "conejo":
            pygame.draw.circle(pantalla, (0, 0, 255), organismo.posicion, 2.5)
        else:
            pygame.draw.circle(pantalla, (255, 0, 0), organismo.posicion, 2.5)
    pygame.display.flip()
    mundo.mostrar_estado()
    mundo.actualizar()
    time.sleep(1)
print("Salida")
# Out:
# --- ciclo 1 ---
# Tipo: conejo, Posición: (95, 100), Energía: 44
# Tipo: zorro, Posición: (110, 125), Energía: 69
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 4
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 4
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 4
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 4
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 4
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 4
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 4
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 4
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 11
# --- ciclo 2 ---
# Tipo: conejo, Posición: (90, 100), Energía: 43
# Tipo: zorro, Posición: (100, 130), Energía: 68
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 3
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 3
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 3
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 3
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 3
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 3
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 3
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 3
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 10
# --- ciclo 3 ---
# Tipo: conejo, Posición: (90, 100), Energía: 42.8
# Tipo: zorro, Posición: (100, 140), Energía: 67
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 2
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 2
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 2
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 2
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 2
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 2
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 2
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 2
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 9
# --- ciclo 4 ---
# Tipo: conejo, Posición: (90, 100), Energía: 42.6
# Tipo: zorro, Posición: (90, 135), Energía: 66
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 1
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 1
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 1
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 1
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 1
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 1
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 1
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 1
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 8
# --- ciclo 5 ---
# Tipo: conejo, Posición: (90, 100), Energía: 66.4
# Tipo: zorro, Posición: (100, 130), Energía: 65
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 20
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 7
# --- ciclo 6 ---
# Tipo: conejo, Posición: (90, 105), Energía: 41.0
# Tipo: zorro, Posición: (100, 130), Energía: 64.8
# Tipo: conejo, Posición: (85, 100), Energía: 41.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 19
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 20
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 6
# --- ciclo 7 ---
# Tipo: conejo, Posición: (95, 110), Energía: 59.0
# Tipo: zorro, Posición: (105, 135), Energía: 63.8
# Tipo: conejo, Posición: (90, 95), Energía: 61.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 18
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 19
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 20
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 20
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 5
# --- ciclo 8 ---
# Tipo: conejo, Posición: (100, 115), Energía: 58.0
# Tipo: zorro, Posición: (115, 135), Energía: 62.8
# Tipo: conejo, Posición: (95, 90), Energía: 80.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 17
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 18
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 19
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 19
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 20
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 4
# --- ciclo 9 ---
# Tipo: zorro, Posición: (115, 125), Energía: 75
# Tipo: conejo, Posición: (95, 90), Energía: 80.0
# Tipo: zorro, Posición: (120, 130), Energía: 75
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 16
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 17
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 18
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 18
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 19
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 20
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 3
# --- ciclo 10 ---
# Tipo: zorro, Posición: (115, 135), Energía: 74
# Tipo: conejo, Posición: (100, 95), Energía: 79.0
# Tipo: zorro, Posición: (115, 140), Energía: 74
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 15
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 16
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 17
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 17
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 18
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 19
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 2
# --- ciclo 11 ---
# Tipo: zorro, Posición: (110, 135), Energía: 73
# Tipo: conejo, Posición: (105, 100), Energía: 50.0
# Tipo: zorro, Posición: (120, 140), Energía: 73
# Tipo: conejo, Posición: (110, 105), Energía: 50.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 14
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 15
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 16
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 16
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 17
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 20
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 18
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 1
# --- ciclo 12 ---
# Tipo: zorro, Posición: (105, 130), Energía: 72
# Tipo: conejo, Posición: (110, 105), Energía: 49.0
# Tipo: zorro, Posición: (130, 145), Energía: 72
# Tipo: conejo, Posición: (115, 110), Energía: 60.0
# Tipo: conejo, Posición: (110, 105), Energía: 60.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 13
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 14
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 15
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 15
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 16
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 19
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 17
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 50
# --- ciclo 13 ---
# Tipo: zorro, Posición: (95, 120), Energía: 71
# Tipo: conejo, Posición: (110, 100), Energía: 48.0
# Tipo: zorro, Posición: (120, 145), Energía: 71
# Tipo: conejo, Posición: (110, 105), Energía: 59.0
# Tipo: conejo, Posición: (110, 100), Energía: 59.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 12
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 13
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 14
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 14
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 15
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 18
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 16
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 49
# --- ciclo 14 ---
# Tipo: zorro, Posición: (95, 125), Energía: 70
# Tipo: conejo, Posición: (110, 95), Energía: 71.0
# Tipo: zorro, Posición: (110, 140), Energía: 70
# Tipo: conejo, Posición: (110, 110), Energía: 58.0
# Tipo: conejo, Posición: (110, 100), Energía: 58.8
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 11
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 12
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 13
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 13
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 14
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 17
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 15
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 20
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 48
# --- ciclo 15 ---
# Tipo: zorro, Posición: (105, 135), Energía: 69
# Tipo: conejo, Posición: (105, 90), Energía: 70.0
# Tipo: zorro, Posición: (100, 150), Energía: 69
# Tipo: conejo, Posición: (110, 110), Energía: 57.8
# Tipo: conejo, Posición: (110, 100), Energía: 58.6
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 10
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 11
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 12
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 12
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 13
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 16
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 14
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 19
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 47
# --- ciclo 16 ---
# Tipo: zorro, Posición: (105, 125), Energía: 68
# Tipo: conejo, Posición: (100, 90), Energía: 69.0
# Tipo: zorro, Posición: (90, 150), Energía: 68
# Tipo: conejo, Posición: (110, 110), Energía: 57.6
# Tipo: conejo, Posición: (110, 100), Energía: 58.4
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 9
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 10
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 11
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 11
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 12
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 15
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 13
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 18
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 46
# --- ciclo 17 ---
# Tipo: zorro, Posición: (100, 135), Energía: 67
# Tipo: conejo, Posición: (100, 90), Energía: 68.8
# Tipo: zorro, Posición: (100, 150), Energía: 67
# Tipo: conejo, Posición: (110, 110), Energía: 57.4
# Tipo: conejo, Posición: (110, 100), Energía: 58.2
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 8
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 9
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 10
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 10
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 11
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 14
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 12
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 17
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 45
# --- ciclo 18 ---
# Tipo: zorro, Posición: (95, 145), Energía: 66
# Tipo: conejo, Posición: (100, 90), Energía: 68.6
# Tipo: zorro, Posición: (100, 145), Energía: 66
# Tipo: conejo, Posición: (110, 110), Energía: 57.2
# Tipo: conejo, Posición: (110, 100), Energía: 58.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 7
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 8
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 9
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 9
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 10
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 13
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 11
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 16
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 44
# --- ciclo 19 ---
# Tipo: zorro, Posición: (95, 155), Energía: 65
# Tipo: conejo, Posición: (100, 90), Energía: 68.4
# Tipo: zorro, Posición: (90, 135), Energía: 65
# Tipo: conejo, Posición: (110, 110), Energía: 57.0
# Tipo: conejo, Posición: (110, 100), Energía: 57.8
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 6
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 7
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 8
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 8
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 9
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 12
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 10
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 15
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 43
# --- ciclo 20 ---
# Tipo: zorro, Posición: (85, 160), Energía: 64
# Tipo: conejo, Posición: (100, 90), Energía: 68.2
# Tipo: zorro, Posición: (100, 140), Energía: 64
# Tipo: conejo, Posición: (110, 110), Energía: 56.8
# Tipo: conejo, Posición: (110, 100), Energía: 57.6
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 5
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 6
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 7
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 7
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 8
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 11
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 9
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 14
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 42
# --- ciclo 21 ---
# Tipo: zorro, Posición: (85, 160), Energía: 63.8
# Tipo: conejo, Posición: (100, 90), Energía: 68.0
# Tipo: zorro, Posición: (95, 135), Energía: 63
# Tipo: conejo, Posición: (110, 110), Energía: 56.6
# Tipo: conejo, Posición: (110, 100), Energía: 57.4
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 4
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 5
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 6
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 6
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 7
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 10
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 8
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 13
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 41
# --- ciclo 22 ---
# Tipo: zorro, Posición: (75, 150), Energía: 62.8
# Tipo: conejo, Posición: (100, 90), Energía: 67.8
# Tipo: zorro, Posición: (85, 130), Energía: 62
# Tipo: conejo, Posición: (110, 110), Energía: 56.4
# Tipo: conejo, Posición: (110, 100), Energía: 57.2
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 3
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 4
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 5
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 5
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 6
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 9
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 7
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 12
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 40
# --- ciclo 23 ---
# Tipo: zorro, Posición: (75, 160), Energía: 61.8
# Tipo: conejo, Posición: (100, 90), Energía: 67.6
# Tipo: zorro, Posición: (85, 120), Energía: 61
# Tipo: conejo, Posición: (110, 110), Energía: 56.2
# Tipo: conejo, Posición: (110, 100), Energía: 57.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 2
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 3
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 4
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 4
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 5
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 8
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 6
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 11
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 39
# --- ciclo 24 ---
# Tipo: zorro, Posición: (70, 150), Energía: 60.8
# Tipo: conejo, Posición: (100, 90), Energía: 67.4
# Tipo: zorro, Posición: (80, 115), Energía: 60
# Tipo: conejo, Posición: (110, 110), Energía: 56.0
# Tipo: conejo, Posición: (110, 100), Energía: 56.8
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 1
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 2
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 3
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 3
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 4
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 7
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 5
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 10
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 38
# --- ciclo 25 ---
# Tipo: zorro, Posición: (60, 145), Energía: 59.8
# Tipo: conejo, Posición: (100, 90), Energía: 67.2
# Tipo: zorro, Posición: (80, 105), Energía: 59
# Tipo: conejo, Posición: (110, 110), Energía: 55.8
# Tipo: conejo, Posición: (110, 100), Energía: 56.6
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 1
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 2
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 2
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 3
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 6
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 4
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 9
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 37
# --- ciclo 26 ---
# Tipo: zorro, Posición: (50, 140), Energía: 58.8
# Tipo: zorro, Posición: (90, 100), Energía: 74.0
# Tipo: conejo, Posición: (110, 110), Energía: 55.8
# Tipo: conejo, Posición: (110, 100), Energía: 56.4
# Tipo: zorro, Posición: (85, 105), Energía: 74.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 1
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 1
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 2
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 5
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 3
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 8
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 36
# --- ciclo 27 ---
# Tipo: zorro, Posición: (45, 140), Energía: 57.8
# Tipo: zorro, Posición: (85, 105), Energía: 73.0
# Tipo: conejo, Posición: (110, 110), Energía: 55.6
# Tipo: conejo, Posición: (110, 100), Energía: 56.2
# Tipo: zorro, Posición: (80, 115), Energía: 73.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 1
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 4
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 2
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 7
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 35
# --- ciclo 28 ---
# Tipo: zorro, Posición: (50, 145), Energía: 56.8
# Tipo: zorro, Posición: (90, 100), Energía: 72.0
# Tipo: conejo, Posición: (110, 110), Energía: 55.4
# Tipo: conejo, Posición: (110, 100), Energía: 56.0
# Tipo: zorro, Posición: (75, 115), Energía: 72.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 3
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 1
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 6
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 34
# --- ciclo 29 ---
# Tipo: zorro, Posición: (60, 140), Energía: 55.8
# Tipo: zorro, Posición: (85, 95), Energía: 71.0
# Tipo: conejo, Posición: (110, 110), Energía: 75.2
# Tipo: conejo, Posición: (110, 100), Energía: 55.8
# Tipo: zorro, Posición: (70, 115), Energía: 71.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 2
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 20
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 5
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 33
# --- ciclo 30 ---
# Tipo: zorro, Posición: (50, 130), Energía: 54.8
# Tipo: zorro, Posición: (80, 90), Energía: 70.0
# Tipo: conejo, Posición: (105, 110), Energía: 49.0
# Tipo: conejo, Posición: (110, 100), Energía: 55.6
# Tipo: zorro, Posición: (70, 110), Energía: 70.0
# Tipo: conejo, Posición: (100, 115), Energía: 49.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 20
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 1
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 19
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 4
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 32
# --- ciclo 31 ---
# Tipo: zorro, Posición: (45, 120), Energía: 53.8
# Tipo: zorro, Posición: (75, 90), Energía: 69.0
# Tipo: conejo, Posición: (110, 105), Energía: 72.0
# Tipo: conejo, Posición: (105, 95), Energía: 70.6
# Tipo: zorro, Posición: (80, 120), Energía: 69.0
# Tipo: conejo, Posición: (95, 110), Energía: 68.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 0
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 20
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 19
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 20
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 20
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 18
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 3
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 31
# --- ciclo 32 ---
# Tipo: zorro, Posición: (40, 125), Energía: 52.8
# Tipo: zorro, Posición: (70, 80), Energía: 68.0
# Tipo: conejo, Posición: (110, 100), Energía: 71.0
# Tipo: conejo, Posición: (110, 90), Energía: 69.6
# Tipo: zorro, Posición: (70, 120), Energía: 68.0
# Tipo: conejo, Posición: (90, 105), Energía: 45.0
# Tipo: conejo, Posición: (85, 100), Energía: 45.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 20
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 19
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 0
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 18
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 19
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 19
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 17
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 2
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 30
# --- ciclo 33 ---
# Tipo: zorro, Posición: (30, 120), Energía: 51.8
# Tipo: zorro, Posición: (70, 80), Energía: 67.8
# Tipo: conejo, Posición: (110, 95), Energía: 70.0
# Tipo: conejo, Posición: (110, 90), Energía: 69.4
# Tipo: zorro, Posición: (75, 130), Energía: 67.0
# Tipo: conejo, Posición: (90, 100), Energía: 44.0
# Tipo: conejo, Posición: (90, 95), Energía: 62.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 19
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 18
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 20
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 17
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 18
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 18
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 16
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 1
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 29
# --- ciclo 34 ---
# Tipo: zorro, Posición: (40, 110), Energía: 50.8
# Tipo: zorro, Posición: (70, 85), Energía: 66.8
# Tipo: conejo, Posición: (110, 90), Energía: 43.0
# Tipo: conejo, Posición: (110, 90), Energía: 69.2
# Tipo: zorro, Posición: (85, 135), Energía: 66.0
# Tipo: conejo, Posición: (90, 100), Energía: 43.8
# Tipo: conejo, Posición: (90, 100), Energía: 61.0
# Tipo: conejo, Posición: (115, 95), Energía: 43.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 18
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 17
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 19
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 16
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 17
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 17
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 15
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 20
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 28
# --- ciclo 35 ---
# Tipo: zorro, Posición: (50, 110), Energía: 49.8
# Tipo: zorro, Posición: (75, 75), Energía: 65.8
# Tipo: conejo, Posición: (110, 90), Energía: 42.8
# Tipo: conejo, Posición: (110, 90), Energía: 69.0
# Tipo: zorro, Posición: (95, 135), Energía: 65.0
# Tipo: conejo, Posición: (90, 100), Energía: 43.6
# Tipo: conejo, Posición: (90, 100), Energía: 60.8
# Tipo: conejo, Posición: (110, 100), Energía: 42.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 17
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 16
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 18
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 15
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 16
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 16
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 14
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 19
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 27
# --- ciclo 36 ---
# Tipo: zorro, Posición: (40, 110), Energía: 48.8
# Tipo: zorro, Posición: (75, 85), Energía: 64.8
# Tipo: conejo, Posición: (110, 90), Energía: 42.6
# Tipo: conejo, Posición: (110, 90), Energía: 68.8
# Tipo: zorro, Posición: (105, 140), Energía: 64.0
# Tipo: conejo, Posición: (90, 100), Energía: 43.4
# Tipo: conejo, Posición: (90, 100), Energía: 60.6
# Tipo: conejo, Posición: (110, 100), Energía: 41.8
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 16
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 15
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 17
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 14
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 15
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 15
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 13
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 18
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 26
# --- ciclo 37 ---
# Tipo: zorro, Posición: (35, 120), Energía: 47.8
# Tipo: zorro, Posición: (75, 85), Energía: 64.6
# Tipo: conejo, Posición: (110, 90), Energía: 42.4
# Tipo: conejo, Posición: (110, 90), Energía: 68.6
# Tipo: zorro, Posición: (95, 130), Energía: 63.0
# Tipo: conejo, Posición: (90, 100), Energía: 43.2
# Tipo: conejo, Posición: (90, 100), Energía: 60.4
# Tipo: conejo, Posición: (110, 100), Energía: 41.6
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 15
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 14
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 16
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 13
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 14
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 14
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 12
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 17
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 25
# --- ciclo 38 ---
# Tipo: zorro, Posición: (30, 125), Energía: 46.8
# Tipo: zorro, Posición: (70, 75), Energía: 63.6
# Tipo: conejo, Posición: (110, 90), Energía: 42.2
# Tipo: conejo, Posición: (110, 90), Energía: 68.4
# Tipo: zorro, Posición: (105, 130), Energía: 62.0
# Tipo: conejo, Posición: (90, 100), Energía: 43.0
# Tipo: conejo, Posición: (90, 100), Energía: 60.2
# Tipo: conejo, Posición: (110, 100), Energía: 41.4
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 14
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 13
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 15
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 12
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 13
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 13
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 11
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 16
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 24
# --- ciclo 39 ---
# Tipo: zorro, Posición: (35, 135), Energía: 45.8
# Tipo: zorro, Posición: (75, 85), Energía: 62.6
# Tipo: conejo, Posición: (110, 90), Energía: 42.0
# Tipo: conejo, Posición: (110, 90), Energía: 68.2
# Tipo: zorro, Posición: (105, 130), Energía: 61.8
# Tipo: conejo, Posición: (90, 100), Energía: 42.8
# Tipo: conejo, Posición: (90, 100), Energía: 60.0
# Tipo: conejo, Posición: (110, 100), Energía: 41.2
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 13
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 12
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 14
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 11
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 12
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 12
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 10
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 15
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 23
# --- ciclo 40 ---
# Tipo: zorro, Posición: (40, 135), Energía: 44.8
# Tipo: zorro, Posición: (70, 85), Energía: 61.6
# Tipo: conejo, Posición: (110, 90), Energía: 41.8
# Tipo: conejo, Posición: (110, 90), Energía: 68.0
# Tipo: zorro, Posición: (100, 120), Energía: 60.8
# Tipo: conejo, Posición: (90, 100), Energía: 42.6
# Tipo: conejo, Posición: (90, 100), Energía: 59.8
# Tipo: conejo, Posición: (110, 100), Energía: 41.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 12
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 11
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 13
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 10
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 11
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 11
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 9
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 14
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 22
# --- ciclo 41 ---
# Tipo: zorro, Posición: (35, 135), Energía: 43.8
# Tipo: zorro, Posición: (75, 90), Energía: 60.6
# Tipo: conejo, Posición: (110, 90), Energía: 41.6
# Tipo: conejo, Posición: (110, 90), Energía: 67.8
# Tipo: zorro, Posición: (105, 110), Energía: 62.0
# Tipo: conejo, Posición: (90, 100), Energía: 42.4
# Tipo: conejo, Posición: (90, 100), Energía: 59.6
# Tipo: zorro, Posición: (110, 115), Energía: 62.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 11
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 10
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 12
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 9
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 10
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 10
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 8
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 13
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 21
# --- ciclo 42 ---
# Tipo: zorro, Posición: (35, 135), Energía: 43.6
# Tipo: zorro, Posición: (65, 90), Energía: 59.6
# Tipo: conejo, Posición: (110, 90), Energía: 41.4
# Tipo: conejo, Posición: (110, 90), Energía: 67.6
# Tipo: zorro, Posición: (115, 110), Energía: 61.0
# Tipo: conejo, Posición: (90, 100), Energía: 42.2
# Tipo: conejo, Posición: (90, 100), Energía: 59.4
# Tipo: zorro, Posición: (115, 125), Energía: 61.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 10
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 9
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 11
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 8
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 9
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 9
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 7
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 12
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 20
# --- ciclo 43 ---
# Tipo: zorro, Posición: (40, 135), Energía: 42.6
# Tipo: zorro, Posición: (70, 90), Energía: 58.6
# Tipo: conejo, Posición: (110, 90), Energía: 41.2
# Tipo: conejo, Posición: (110, 90), Energía: 67.4
# Tipo: zorro, Posición: (105, 105), Energía: 60.0
# Tipo: conejo, Posición: (90, 100), Energía: 42.0
# Tipo: conejo, Posición: (90, 100), Energía: 59.2
# Tipo: zorro, Posición: (110, 115), Energía: 60.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 9
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 8
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 10
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 7
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 8
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 8
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 6
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 11
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 19
# --- ciclo 44 ---
# Tipo: zorro, Posición: (30, 135), Energía: 41.6
# Tipo: zorro, Posición: (60, 80), Energía: 57.6
# Tipo: conejo, Posición: (110, 90), Energía: 67.2
# Tipo: zorro, Posición: (105, 95), Energía: 55.0
# Tipo: conejo, Posición: (90, 100), Energía: 42.0
# Tipo: conejo, Posición: (90, 100), Energía: 59.0
# Tipo: zorro, Posición: (115, 105), Energía: 59.0
# Tipo: zorro, Posición: (100, 100), Energía: 55.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 8
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 7
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 9
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 6
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 7
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 7
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 5
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 10
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 18
# --- ciclo 45 ---
# Tipo: zorro, Posición: (30, 130), Energía: 40.6
# Tipo: zorro, Posición: (50, 75), Energía: 56.6
# Tipo: zorro, Posición: (95, 85), Energía: 54.0
# Tipo: conejo, Posición: (90, 100), Energía: 41.8
# Tipo: conejo, Posición: (90, 100), Energía: 58.8
# Tipo: zorro, Posición: (110, 100), Energía: 66.0
# Tipo: zorro, Posición: (100, 100), Energía: 55.0
# Tipo: zorro, Posición: (105, 95), Energía: 66.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 7
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 6
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 8
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 5
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 6
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 6
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 4
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 9
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 17
# --- ciclo 46 ---
# Tipo: zorro, Posición: (30, 120), Energía: 39.6
# Tipo: zorro, Posición: (40, 80), Energía: 55.6
# Tipo: zorro, Posición: (95, 90), Energía: 57.0
# Tipo: zorro, Posición: (110, 95), Energía: 65.0
# Tipo: zorro, Posición: (110, 110), Energía: 54.0
# Tipo: zorro, Posición: (95, 90), Energía: 67.0
# Tipo: zorro, Posición: (90, 85), Energía: 57.0
# Tipo: zorro, Posición: (100, 85), Energía: 67.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 6
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 5
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 7
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 4
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 5
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 5
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 3
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 8
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 16
# --- ciclo 47 ---
# Tipo: zorro, Posición: (30, 130), Energía: 38.6
# Tipo: zorro, Posición: (45, 75), Energía: 54.6
# Tipo: zorro, Posición: (105, 80), Energía: 56.0
# Tipo: zorro, Posición: (120, 95), Energía: 64.0
# Tipo: zorro, Posición: (115, 105), Energía: 53.0
# Tipo: zorro, Posición: (85, 85), Energía: 66.0
# Tipo: zorro, Posición: (95, 80), Energía: 56.0
# Tipo: zorro, Posición: (90, 75), Energía: 66.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 5
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 4
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 6
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 3
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 4
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 4
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 2
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 7
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 15
# --- ciclo 48 ---
# Tipo: zorro, Posición: (20, 120), Energía: 37.6
# Tipo: zorro, Posición: (35, 70), Energía: 53.6
# Tipo: zorro, Posición: (100, 80), Energía: 55.0
# Tipo: zorro, Posición: (125, 90), Energía: 63.0
# Tipo: zorro, Posición: (115, 95), Energía: 52.0
# Tipo: zorro, Posición: (95, 80), Energía: 65.0
# Tipo: zorro, Posición: (90, 70), Energía: 55.0
# Tipo: zorro, Posición: (85, 70), Energía: 65.0
# _________ Tipo: arbusto, Posición: (90, 100), Recuperación: 4
# _________ Tipo: arbusto, Posición: (90, 110), Recuperación: 3
# _________ Tipo: arbusto, Posición: (90, 90), Recuperación: 5
# _________ Tipo: arbusto, Posición: (100, 110), Recuperación: 2
# _________ Tipo: arbusto, Posición: (100, 90), Recuperación: 3
# _________ Tipo: arbusto, Posición: (110, 100), Recuperación: 3
# _________ Tipo: arbusto, Posición: (110, 110), Recuperación: 1
# _________ Tipo: arbusto, Posición: (110, 90), Recuperación: 6
# _________ Tipo: arbusto, Posición: (120, 115), Recuperación: 14
# Salida
